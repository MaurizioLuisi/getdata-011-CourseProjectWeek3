# %% [markdown]
# # Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# # Scraping the data and loading it into a Pandas dataframe

# %%
# The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
column_names = ['Postalcode', 'Borough', 'Neighborhood'] 

# Create dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# load libraries for scraping data
from bs4 import BeautifulSoup
import urllib.request
def make_soup(url):
    wikipage = urllib.request.urlopen(url)
    soupdata = BeautifulSoup(wikipage, "html.parser")
    return soupdata

soup = make_soup("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# find the table
table = soup.find_all('table', class_="wikitable sortable")[0]  

# iterate over it
wikidatasaved = []
for item in table.findAll('tr'):
    wikidata = []
    for data in item.findAll('td'):
        wikidata.append(data.text)
    if len(wikidata) == 3:
        neighborhoods = neighborhoods.append({'Postalcode': wikidata[0],
                                          'Borough': wikidata[1],
                                          'Neighborhood': wikidata[2]}, ignore_index=True)

# remove newline from Neighborhood column
neighborhoods['Neighborhood'] = neighborhoods['Neighborhood'].map(lambda x: str(x)[:-1])
neighborhoods.head()
# Out:
#   Postalcode           Borough      Neighborhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %%
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
neighborhoods = neighborhoods[neighborhoods['Borough'] != 'Not assigned'].reset_index(drop = True)
neighborhoods.head()
# Out:
#   Postalcode           Borough      Neighborhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights

# %%
# More than one neighborhood can exist in one postal code area. Combining them into one row the neighborhoods separated with a comma  
neighborhoods = neighborhoods.groupby([neighborhoods.Postalcode, neighborhoods.Borough], as_index=False).agg(', '.join)
neighborhoods.head()
# Out:
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. 
neighborhoods['Neighborhood'].loc[neighborhoods['Neighborhood'] == 'Not assigned'] = neighborhoods['Borough']

# %%
neighborhoods.shape
# Out:
# (103, 3)

# %% [markdown]
# # Get the latitude and the longitude coordinates of each neighborhood

# %%
locations = pd.read_csv('http://cocl.us/Geospatial_data')
neighborhoods = neighborhoods.join(locations)
neighborhoods.head(11)
# Out:
#    Postalcode      Borough                                       Neighborhood  \
# 0         M1B  Scarborough                                     Rouge, Malvern
# 1         M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2         M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                             Woburn
# 4         M1H  Scarborough                                          Cedarbrae
# 5         M1J  Scarborough                                Scarborough Village
# 6         M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 7         M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 8         M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 9         M1N  Scarborough                        Birch Cliff, Cliffside West
# 10        M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
#
#    Postal Code   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# 5          M1J  43.744734 -79.239476
# 6          M1K  43.727929 -79.262029
# 7          M1L  43.711112 -79.284577
# 8          M1M  43.716316 -79.239476
# 9          M1N  43.692657 -79.264848
# 10         M1P  43.757410 -79.273304

# %%
neighborhoods.drop('Postal Code', axis=1, inplace=True)
neighborhoods.head(11)
# Out:
#    Postalcode      Borough                                       Neighborhood  \
# 0         M1B  Scarborough                                     Rouge, Malvern
# 1         M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2         M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                             Woburn
# 4         M1H  Scarborough                                          Cedarbrae
# 5         M1J  Scarborough                                Scarborough Village
# 6         M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 7         M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 8         M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 9         M1N  Scarborough                        Birch Cliff, Cliffside West
# 10        M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
#
#      Latitude  Longitude
# 0   43.806686 -79.194353
# 1   43.784535 -79.160497
# 2   43.763573 -79.188711
# 3   43.770992 -79.216917
# 4   43.773136 -79.239476
# 5   43.744734 -79.239476
# 6   43.727929 -79.262029
# 7   43.711112 -79.284577
# 8   43.716316 -79.239476
# 9   43.692657 -79.264848
# 10  43.757410 -79.273304

# %% [markdown]
# # Explore and cluster the neighborhoods in Toronto

# %%
# convert an address into latitude and longitude values
address = 'Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.19.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Use Foursquare API to explore and segment neighborhoods
CLIENT_ID = 'REMOVED' # your Foursquare ID
CLIENT_SECRET = 'REMOVED' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# Let's take a look at the first postcode in our Toronto dataframe and get its coordinates:
neighborhoods.loc[0, 'Neighborhood']

neighborhood_latitude = neighborhoods.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = neighborhoods.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = neighborhoods.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Rouge, Malvern are 43.806686299999996, -79.19435340000001.

# %%
# use the Foursquare API to get the top 100 venues that are in Toronto within a radius of 1000 meters from its center coordinates
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 1000 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

results = requests.get(url).json()
results # display results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce6908c9fb6b77580a60b62'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d669cba83865481c948fa53-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '4d669cba83865481c948fa53',
#        'location': {'address': '8130 Sheppard Ave E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Morningside Ave',
#         'distance': 595,
#         'formattedAddress': ['8130 Sheppard Ave E (Morningside Ave)',
#          'Toronto ON M1B 3W3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80228301948931,
#           'lng': -79.19856472801668}],
#         'lat': 43.80228301948931,
#         'lng': -79.19856472801668,
#         'postalCode': 'M1B 3W3',
#         'state': 'ON'},
#        'name': 'Images Salon & Spa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b914562f964a520d4ae33e3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'primary': True,
#          'shortName': 'Caribbean'}],
#        'id': '4b914562f964a520d4ae33e3',
#        'location': {'address': '875 Milner Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Milner and Morningside',
#         'distance': 912,
#         'formattedAddress': ['875 Milner Ave (Milner and Morningside)',
#          'Toronto ON M1B',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.798557859976256,
#           'lng': -79.19577725412623}],
#         'lat': 43.798557859976256,
#         'lng': -79.19577725412623,
#         'postalCode': 'M1B',
#         'state': 'ON'},
#        'name': 'Caribbean Wave',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bcb612d3740b713f0606265-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d121951735',
#          'name': 'Paper / Office Supplies Store',
#          'pluralName': 'Paper / Office Supplies Stores',
#          'primary': True,
#          'shortName': 'Office Supplies'}],
#        'id': '4bcb612d3740b713f0606265',
#        'location': {'address': '850 Milner Avenue',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'distance': 735,
#         'formattedAddress': ['850 Milner Avenue',
#          'Scarborough ON M1B 5N7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80028467632823,
#           'lng': -79.19660657644272}],
#         'lat': 43.80028467632823,
#         'lng': -79.19660657644272,
#         'postalCode': 'M1B 5N7',
#         'state': 'ON'},
#        'name': 'Staples Morningside',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-579a91b3498e9bd833afa78a-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '579a91b3498e9bd833afa78a',
#        'location': {'address': '8129 Sheppard Avenue',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'distance': 600,
#         'formattedAddress': ['8129 Sheppard Avenue',
#          'Scarborough ON M1B 6A3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.8020084,
#           'lng': -79.1980797}],
#         'lat': 43.8020084,
#         'lng': -79.1980797,
#         'postalCode': 'M1B 6A3',
#         'state': 'ON'},
#        'name': "Wendy's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bb6b9446edc76b0d771311c-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4bb6b9446edc76b0d771311c',
#        'location': {'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Morningside & Sheppard',
#         'distance': 387,
#         'formattedAddress': ['Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80744841934756,
#           'lng': -79.19905558052072}],
#         'lat': 43.80744841934756,
#         'lng': -79.19905558052072,
#         'state': 'ON'},
#        'name': "Wendy's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6718c2f964a5203f3a2be3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4b6718c2f964a5203f3a2be3',
#        'location': {'address': '853 Milner Ave',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'crossStreet': 'at Morningside Ave',
#         'distance': 796,
#         'formattedAddress': ['853 Milner Ave (at Morningside Ave)',
#          'Scarborough ON M1B 5N6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80010575211872,
#           'lng': -79.19825833589329}],
#         'lat': 43.80010575211872,
#         'lng': -79.19825833589329,
#         'postalCode': 'M1B 5N6',
#         'state': 'ON'},
#        'name': "Harvey's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b16e23bf964a520edbe23e3-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b16e23bf964a520edbe23e3',
#        'location': {'address': '8129 Sheppard Ave',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'crossStreet': 'Morningside Ave',
#         'distance': 605,
#         'formattedAddress': ['8129 Sheppard Ave (Morningside Ave)',
#          'Scarborough ON M1B 6A3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.801999861382,
#           'lng': -79.1981689631939}],
#         'lat': 43.801999861382,
#         'lng': -79.1981689631939,
#         'postalCode': 'M1B 6A3',
#         'state': 'ON'},
#        'name': 'Tim Hortons',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd08ceeb221c9b6cbe8d3d0-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hobbyshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fb941735',
#          'name': 'Hobby Shop',
#          'pluralName': 'Hobby Shops',
#          'primary': True,
#          'shortName': 'Hobbies'}],
#        'id': '4bd08ceeb221c9b6cbe8d3d0',
#        'location': {'address': '1275 Morningside',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 580,
#         'formattedAddress': ['1275 Morningside', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.803161304831846,
#           'lng': -79.19968142252247}],
#         'lat': 43.803161304831846,
#         'lng': -79.19968142252247,
#         'state': 'ON'},
#        'name': 'Lee Valley',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bff1f63d69ed0002cca9a0d-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '5453de49498eade8af355881',
#          'name': 'Business Service',
#          'pluralName': 'Business Services',
#          'primary': True,
#          'shortName': 'Business Services'}],
#        'id': '5bff1f63d69ed0002cca9a0d',
#        'location': {'address': '4-1365 Morningside Ave.',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'distance': 626,
#         'formattedAddress': ['4-1365 Morningside Ave.',
#          'Scarborough ON M1B 4Y5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.8078818,
#           'lng': -79.2019677}],
#         'lat': 43.8078818,
#         'lng': -79.2019677,
#         'postalCode': 'M1B 4Y5',
#         'state': 'ON'},
#        'name': 'FASTSIGNS',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e25ba8fd164b6b74afdd029-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'primary': True,
#          'shortName': 'Bus Station'}],
#        'id': '4e25ba8fd164b6b74afdd029',
#        'location': {'address': 'Sheppard & Morningside',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'distance': 642,
#         'formattedAddress': ['Sheppard & Morningside',
#          'Scarborough ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80219845231118,
#           'lng': -79.19938862774073}],
#         'lat': 43.80219845231118,
#         'lng': -79.19938862774073,
#         'state': 'ON'},
#        'name': 'Bus Stop: 85 & 116',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5001cb14e4b041fa0a28ee80-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d101941735',
#          'name': 'Martial Arts Dojo',
#          'pluralName': 'Martial Arts Dojos',
#          'primary': True,
#          'shortName': 'Martial Arts'}],
#        'id': '5001cb14e4b041fa0a28ee80',
#        'location': {'address': '15 Grand Marshall Drive, Suite 2',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'distance': 718,
#         'formattedAddress': ['15 Grand Marshall Drive, Suite 2',
#          'Scarborough ON M1B 5N6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80025935327685,
#           'lng': -79.19522661480777}],
#         'lat': 43.80025935327685,
#         'lng': -79.19522661480777,
#         'postalCode': 'M1B 5N6',
#         'state': 'ON'},
#        'name': 'MMA World Academy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ceaa2f0f8653704f906bec4-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c8941735',
#          'name': 'African Restaurant',
#          'pluralName': 'African Restaurants',
#          'primary': True,
#          'shortName': 'African'}],
#        'id': '4ceaa2f0f8653704f906bec4',
#        'location': {'address': '1161 Morningside Avenue',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Morningside &Sheppard',
#         'distance': 743,
#         'formattedAddress': ['1161 Morningside Avenue (Morningside &Sheppard)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.801262219554275,
#           'lng': -79.19975818333775}],
#         'lat': 43.801262219554275,
#         'lng': -79.19975818333775,
#         'state': 'ON'},
#        'name': 'Mr Jerk',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59a495dc66f3cd3397ea8d4d-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d5734d3',
#          'name': 'Auto Workshop',
#          'pluralName': 'Auto Workshops',
#          'primary': True,
#          'shortName': 'Auto Workshop'}],
#        'id': '59a495dc66f3cd3397ea8d4d',
#        'location': {'address': '898 Milner Avenue',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'distance': 786,
#         'formattedAddress': ['898 Milner Avenue',
#          'Scarborough ON M1B 5N7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7997751,
#           'lng': -79.19230519999999}],
#         'lat': 43.7997751,
#         'lng': -79.19230519999999,
#         'postalCode': 'M1B 5N7',
#         'state': 'ON'},
#        'name': 'FIX AUTO SCARBOROUGH EAST ROUGE',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c706524df6b8cfab244b84d-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4c706524df6b8cfab244b84d',
#        'location': {'address': '3-1158 Morningside Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Sheppard Ave',
#         'distance': 791,
#         'formattedAddress': ['3-1158 Morningside Ave (Sheppard Ave)',
#          'Toronto ON M1B 3A4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80098159718747,
#           'lng': -79.20023292303085}],
#         'lat': 43.80098159718747,
#         'lng': -79.20023292303085,
#         'postalCode': 'M1B 3A4',
#         'state': 'ON'},
#        'name': "Charley's Exotic Cuisine",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b60878af964a520d9eb29e3-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4b60878af964a520d9eb29e3',
#        'location': {'address': '855 Milner Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Morningside Ave',
#         'distance': 822,
#         'formattedAddress': ['855 Milner Ave (at Morningside Ave)',
#          'Toronto ON M1B 2W4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.799853406744745,
#           'lng': -79.19823358305395}],
#         'lat': 43.799853406744745,
#         'lng': -79.19823358305395,
#         'postalCode': 'M1B 2W4',
#         'state': 'ON'},
#        'name': 'MR. GREEK Express',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-539641d9498ee4f723c48089-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b1c',
#          'name': 'Fruit & Vegetable Store',
#          'pluralName': 'Fruit & Vegetable Stores',
#          'primary': True,
#          'shortName': 'Fruit & Vegetable Store'}],
#        'id': '539641d9498ee4f723c48089',
#        'location': {'address': '1150 Morningside Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Milner',
#         'distance': 824,
#         'formattedAddress': ['1150 Morningside Ave (Milner)',
#          'Toronto ON M1B 3A4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.800527899352915,
#           'lng': -79.2000637571665}],
#         'lat': 43.800527899352915,
#         'lng': -79.2000637571665,
#         'postalCode': 'M1B 3A4',
#         'state': 'ON'},
#        'name': 'Fusion Supermarket',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55e34982498ea9b7a8027f90-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '55e34982498ea9b7a8027f90',
#        'location': {'address': '855 Milner Ave',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'country': 'Canada',
#         'distance': 840,
#         'formattedAddress': ['855 Milner Ave',
#          'Scarborough ON M1B 5N6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.799668506947064,
#           'lng': -79.19820682728174}],
#         'lat': 43.799668506947064,
#         'lng': -79.19820682728174,
#         'postalCode': 'M1B 5N6',
#         'state': 'ON'},
#        'name': 'Fit4Less',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf01bf43a002d7f50ac85a4-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4bf01bf43a002d7f50ac85a4',
#        'location': {'address': '875 Milner Avenue',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 884,
#         'formattedAddress': ['875 Milner Avenue',
#          'Toronto ON M1B 5N6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.798888,
#           'lng': -79.196473}],
#         'lat': 43.798888,
#         'lng': -79.196473,
#         'postalCode': 'M1B 5N6',
#         'state': 'ON'},
#        'name': 'What a Bakery',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf02131f831c928359c01f2-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d127951735',
#          'name': 'Arts & Crafts Store',
#          'pluralName': 'Arts & Crafts Stores',
#          'primary': True,
#          'shortName': 'Arts & Crafts'}],
#        'id': '4bf02131f831c928359c01f2',
#        'location': {'cc': 'CA',
#         'country': 'Canada',
#         'distance': 886,
#         'formattedAddress': ['Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.799013800948444,
#           'lng': -79.19731406960719}],
#         'lat': 43.799013800948444,
#         'lng': -79.19731406960719},
#        'name': 'Fabricland',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b89abadf964a520ae4a32e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '4b89abadf964a520ae4a32e3',
#        'location': {'address': '875 Milner Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Morningside Ave',
#         'distance': 898,
#         'formattedAddress': ['875 Milner Ave (at Morningside Ave)',
#          'Toronto ON M1B 5N6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.798773188206816,
#           'lng': -79.19655550872147}],
#         'lat': 43.798773188206816,
#         'lng': -79.19655550872147,
#         'postalCode': 'M1B 5N6',
#         'state': 'ON'},
#        'name': 'Quiznos',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fdb659ee4b0fcb93efc18d7-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4fdb659ee4b0fcb93efc18d7',
#        'location': {'address': '8450 Sheppard Ave E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Conlins and Sheppard',
#         'distance': 939,
#         'formattedAddress': ['8450 Sheppard Ave E (Conlins and Sheppard)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80626621064408,
#           'lng': -79.18267533364352}],
#         'lat': 43.80626621064408,
#         'lng': -79.18267533364352,
#         'state': 'ON'},
#        'name': 'joyce trimmer park',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Malvern, Toronto',
#   'headerLocation': 'Malvern',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 43.81568630900001,
#     'lng': -79.18190576146081},
#    'sw': {'lat': 43.797686290999984, 'lng': -79.20680103853921}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 21}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON data into a Pandas dataframe

# filter columns 
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                   name                     categories        lat        lng
# 0   Images Salon & Spa                            Spa  43.802283 -79.198565
# 1       Caribbean Wave           Caribbean Restaurant  43.798558 -79.195777
# 2  Staples Morningside  Paper / Office Supplies Store  43.800285 -79.196607
# 3              Wendy's           Fast Food Restaurant  43.802008 -79.198080
# 4              Wendy's           Fast Food Restaurant  43.807448 -79.199056

# %%
# Exploring Neighborhoods in Toronto
def getNearbyVenues(names, latitudes, longitudes, radius=2000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=neighborhoods['Neighborhood'],latitudes=neighborhoods['Latitude'],longitudes=neighborhoods['Longitude'])
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens, Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# Downsview, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Islington Avenue
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Humber Summit
# Emery, Humberlea
# Weston
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# Northwest

# %%
# check the size of the dataframe and the top 10 rows:
print(toronto_venues.shape)
toronto_venues.head(10)
# Out:
# (8522, 7)
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Rouge, Malvern              43.806686              -79.194353
# 1  Rouge, Malvern              43.806686              -79.194353
# 2  Rouge, Malvern              43.806686              -79.194353
# 3  Rouge, Malvern              43.806686              -79.194353
# 4  Rouge, Malvern              43.806686              -79.194353
# 5  Rouge, Malvern              43.806686              -79.194353
# 6  Rouge, Malvern              43.806686              -79.194353
# 7  Rouge, Malvern              43.806686              -79.194353
# 8  Rouge, Malvern              43.806686              -79.194353
# 9  Rouge, Malvern              43.806686              -79.194353
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0   African Rainforest Pavilion       43.817725       -79.183433
# 1  Toronto Pan Am Sports Centre       43.790623       -79.193869
# 2             Canadiana exhibit       43.817962       -79.193374
# 3                   Toronto Zoo       43.820582       -79.181551
# 4            Images Salon & Spa       43.802283       -79.198565
# 5               penguin exhibit       43.819435       -79.185959
# 6            Polar Bear Exhibit       43.823372       -79.185145
# 7         Australasia Pavillion       43.822563       -79.183286
# 8               Gorilla Exhibit       43.819080       -79.184235
# 9             Orangutan Exhibit       43.818413       -79.182548
#
#        Venue Category
# 0         Zoo Exhibit
# 1  Athletics & Sports
# 2         Zoo Exhibit
# 3                 Zoo
# 4                 Spa
# 5         Zoo Exhibit
# 6                 Zoo
# 7         Zoo Exhibit
# 8         Zoo Exhibit
# 9         Zoo Exhibit

# %%
# Check how many venues have been returned for each neighborhood given the radius of 1000 meters and the venue limit of 100:
toronto_venues.groupby('Neighborhood')['Neighborhood'].count()
# Out:
# Neighborhood
# Adelaide, King, Richmond                                                                                         100
# Agincourt                                                                                                        100
# Agincourt North, L'Amoreaux East, Milliken, Steeles East                                                          91
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown     44
# Alderwood, Long Branch                                                                                           100
# Bathurst Manor, Downsview North, Wilson Heights                                                                   55
# Bayview Village                                                                                                   46
# Bedford Park, Lawrence Manor East                                                                                100
# Berczy Park                                                                                                      100
# Birch Cliff, Cliffside West                                                                                       48
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe                                                     31
# Brockton, Exhibition Place, Parkdale Village                                                                     100
# Business Reply Mail Processing Centre 969 Eastern                                                                100
# CFB Toronto, Downsview East                                                                                      100
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara       100
# Cabbagetown, St. James Town                                                                                      100
# Caledonia-Fairbanks                                                                                              100
# Canada Post Gateway Processing Centre                                                                            100
# Cedarbrae                                                                                                        100
# Central Bay Street                                                                                               100
# Chinatown, Grange Park, Kensington Market                                                                        100
# Christie                                                                                                         100
# Church and Wellesley                                                                                             100
# Clairlea, Golden Mile, Oakridge                                                                                   95
# Clarks Corners, Sullivan, Tam O'Shanter                                                                           77
# Cliffcrest, Cliffside, Scarborough Village West                                                                   37
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park                                            48
# Commerce Court, Victoria Hotel                                                                                   100
# Davisville                                                                                                       100
# Davisville North                                                                                                 100
#                                                                                                                 ...
# Parkdale, Roncesvalles                                                                                           100
# Parkwoods                                                                                                         87
# Queen's Park                                                                                                     100
# Rosedale                                                                                                         100
# Roselawn                                                                                                         100
# Rouge, Malvern                                                                                                    40
# Runnymede, Swansea                                                                                               100
# Ryerson, Garden District                                                                                         100
# Scarborough Village                                                                                               72
# Silver Hills, York Mills                                                                                         100
# St. James Town                                                                                                   100
# Stn A PO Boxes 25 The Esplanade                                                                                  100
# Studio District                                                                                                  100
# The Annex, North Midtown, Yorkville                                                                              100
# The Beaches                                                                                                      100
# The Beaches West, India Bazaar                                                                                   100
# The Danforth West, Riverdale                                                                                     100
# The Junction North, Runnymede                                                                                     75
# The Kingsway, Montgomery Road, Old Mill North                                                                    100
# Thorncliffe Park                                                                                                 100
# Upper Rouge                                                                                                        5
# Victoria Village                                                                                                 100
# Westmount                                                                                                         53
# Weston                                                                                                            58
# Willowdale South                                                                                                  39
# Willowdale West                                                                                                   53
# Woburn                                                                                                            60
# Woodbine Gardens, Parkview Hill                                                                                   56
# Woodbine Heights                                                                                                 100
# York Mills West                                                                                                  100
# Name: Neighborhood, Length: 103, dtype: int64

# %%
# Unique venue categories have been collected in this dataframe:
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 324 uniques categories.

# %% [markdown]
# # Analyze all neighborhood

# %%
# We find out what kind of venues are in each neighborhood and how frequent these categories of venues are in regards to the total of venues.
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhoods'] = toronto_venues['Neighborhood']

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]
toronto_onehot.shape
#group the rows by neighborhood and by taking the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby('Neighborhoods').mean().reset_index()
toronto_grouped.shape
# Let's find out what the top 5 most common venues for each neighborhood in Toronto are:
num_top_venues = 5

for hood in toronto_grouped['Neighborhoods']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhoods'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#             venue  freq
# 0     Coffee Shop  0.07
# 1           Hotel  0.05
# 2         Theater  0.04
# 3            Café  0.04
# 4  Cosmetics Shop  0.03
#
#
# ----Agincourt----
#                 venue  freq
# 0  Chinese Restaurant  0.12
# 1         Coffee Shop  0.07
# 2            Pharmacy  0.05
# 3   Indian Restaurant  0.03
# 4       Shopping Mall  0.03
#
#
# ----Agincourt North, L'Amoreaux East, Milliken, Steeles East----
#                 venue  freq
# 0  Chinese Restaurant  0.20
# 1         Coffee Shop  0.08
# 2                Park  0.05
# 3         Pizza Place  0.04
# 4   Korean Restaurant  0.03
#
#
# ----Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown----
#                   venue  freq
# 0           Coffee Shop  0.18
# 1  Fast Food Restaurant  0.11
# 2     Indian Restaurant  0.09
# 3           Pizza Place  0.09
# 4         Grocery Store  0.07
#
#
# ----Alderwood, Long Branch----
#                   venue  freq
# 0           Coffee Shop  0.09
# 1          Burger Joint  0.04
# 2  Fast Food Restaurant  0.04
# 3        Clothing Store  0.04
# 4           Pizza Place  0.04
#
#
# ----Bathurst Manor, Downsview North, Wilson Heights----
#             venue  freq
# 0     Coffee Shop  0.07
# 1            Park  0.05
# 2  Sandwich Place  0.05
# 3     Pizza Place  0.05
# 4        Pharmacy  0.05
#
#
# ----Bayview Village----
#                 venue  freq
# 0  Chinese Restaurant  0.11
# 1         Coffee Shop  0.09
# 2                Park  0.09
# 3            Pharmacy  0.07
# 4                Bank  0.07
#
#
# ----Bedford Park, Lawrence Manor East----
#               venue  freq
# 0       Coffee Shop  0.12
# 1            Bakery  0.08
# 2  Sushi Restaurant  0.05
# 3    Sandwich Place  0.04
# 4        Restaurant  0.04
#
#
# ----Berczy Park----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.07
# 2        Hotel  0.05
# 3         Park  0.04
# 4    Gastropub  0.03
#
#
# ----Birch Cliff, Cliffside West----
#                   venue  freq
# 0           Coffee Shop  0.12
# 1                  Park  0.08
# 2         Grocery Store  0.06
# 3                  Bank  0.06
# 4  Fast Food Restaurant  0.04
#
#
# ----Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe----
#            venue  freq
# 0           Bank  0.10
# 1  Grocery Store  0.10
# 2       Pharmacy  0.10
# 3    Coffee Shop  0.10
# 4    Golf Course  0.06
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#             venue  freq
# 0            Café  0.08
# 1     Coffee Shop  0.06
# 2             Bar  0.05
# 3      Restaurant  0.04
# 4  Sandwich Place  0.02
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                 venue  freq
# 0         Coffee Shop  0.08
# 1                Park  0.07
# 2                Café  0.06
# 3             Brewery  0.05
# 4  Italian Restaurant  0.04
#
#
# ----CFB Toronto, Downsview East----
#                  venue  freq
# 0       Clothing Store  0.08
# 1   Athletics & Sports  0.04
# 2          Coffee Shop  0.04
# 3       Cosmetics Shop  0.03
# 4  American Restaurant  0.03
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#

#                    venue  freq
# 0            Coffee Shop  0.11
# 1  Vietnamese Restaurant  0.09
# 2   Fast Food Restaurant  0.08
# 3            Pizza Place  0.05
# 4          Grocery Store  0.05
#
#
# ----East Birchmount Park, Ionview, Kennedy Park----
#                   venue  freq
# 0    Chinese Restaurant  0.09
# 1  Fast Food Restaurant  0.07
# 2           Coffee Shop  0.07
# 3         Grocery Store  0.07
# 4              Pharmacy  0.05
#
#
# ----East Toronto----
#               venue  freq
# 0  Greek Restaurant  0.09
# 1              Café  0.06
# 2       Pizza Place  0.04
# 3       Coffee Shop  0.04
# 4            Bakery  0.04
#
#
# ----Emery, Humberlea----
#             venue  freq
# 0   Grocery Store  0.11
# 1     Coffee Shop  0.09
# 2  Discount Store  0.05
# 3            Bank  0.05
# 4  Clothing Store  0.05
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0           Coffee Shop  0.14
# 1        Clothing Store  0.06
# 2  Fast Food Restaurant  0.05
# 3           Pizza Place  0.04
# 4              Pharmacy  0.04
#
#
# ----First Canadian Place, Underground city----
#          venue  freq
# 0         Café  0.05
# 1        Hotel  0.05
# 2  Coffee Shop  0.04
# 3      Theater  0.04
# 4  Pizza Place  0.03
#
#
# ----Flemingdon Park, Don Mills South----
#                        venue  freq
# 0                Coffee Shop  0.09
# 1                       Park  0.05
# 2        Japanese Restaurant  0.04
# 3                        Gym  0.03
# 4  Middle Eastern Restaurant  0.03
#
#
# ----Forest Hill North, Forest Hill West----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1  Italian Restaurant  0.08
# 2                Café  0.06
# 3    Sushi Restaurant  0.04
# 4              Bakery  0.03
#
#
# ----Glencairn----
#                     venue  freq
# 0          Clothing Store  0.12
# 1             Coffee Shop  0.08
# 2  Furniture / Home Store  0.05
# 3    Fast Food Restaurant  0.04
# 4     Fried Chicken Joint  0.03
#
#
# ----Guildwood, Morningside, West Hill----
#                   venue  freq
# 0           Pizza Place  0.18
# 1           Coffee Shop  0.05
# 2  Fast Food Restaurant  0.05
# 3                  Park  0.05
# 4        Breakfast Spot  0.05
#
#
# ----Harbord, University of Toronto----
#                            venue  freq
# 0                           Café  0.09
# 1                    Coffee Shop  0.05
# 2                 Sandwich Place  0.05
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                            Bar  0.04
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#          venue  freq
# 0         Café  0.08
# 1  Coffee Shop  0.06
# 2        Hotel  0.06
# 3         Park  0.03
# 4          Gym  0.03
#
#
# ----Harbourfront, Regent Park----
#              venue  freq
# 0      Coffee Shop  0.12
# 1             Café  0.06
# 2             Park  0.06
# 3       Restaurant  0.05
# 4  Thai Restaurant  0.04
#
#
# ----High Park, The Junction South----
#                 venue  freq
# 0                Café  0.10
# 1         Coffee Shop  0.09
# 2  Italian Restaurant  0.07
# 3                 Bar  0.06
# 4              Bakery  0.05
#
#
# ----Highland Creek, Rouge Hill, Port Union----
#             venue  freq
# 0     Coffee Shop  0.09
# 1  Breakfast Spot  0.09
# 2  Sandwich Place  0.06
# 3       Pet Store  0.06
# 4    Liquor Store  0.03
#
#
# ----Hillcrest Village----
#                 venue  freq
# 0         Coffee Shop  0.14
# 1  Chinese Restaurant  0.06
# 2                Bank  0.06
# 3      Sandwich Place  0.06
# 4                Park  0.06
#
#
# ----Humber Bay Shores, Mimico South, New Toronto----
#                venue  freq
# 0               Park  0.12
# 1     Sandwich Place  0.04
# 2  Indian Restaurant  0.04
# 3        Coffee Shop  0.04
# 4             Bakery  0.04
#
#
# ----Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1    Sushi Restaurant  0.06
# 2  Italian Restaurant  0.06
# 3          Restaurant  0.04
# 4         Pizza Place  0.04
#
#
# ----Humber Summit----
#                   venue  freq
# 0           Coffee Shop  0.15
# 1                  Bank  0.07
# 2      Asian Restaurant  0.07
# 3  Fast Food Restaurant  0.07
# 4                  Park  0.07
#
#
# ----Humewood-Cedarvale----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.08
# 2                Bank  0.05
# 3         Pizza Place  0.04
# 4              Bakery  0.04
#
#
# ----Islington Avenue----
#            venue  freq
# 0           Park  0.12
# 1    Coffee Shop  0.07
# 2  Shopping Mall  0.07
# 3  Grocery Store  0.05
# 4   Liquor Store  0.05
#
#
# ----Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips----
#             venue  freq
# 0     Coffee Shop  0.11
# 1     Pizza Place  0.09
# 2  Sandwich Place  0.09
# 3        Pharmacy  0.07
# 4     Supermarket  0.05
#
#
# ----Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor----
#                   venue  freq
# 0           Coffee Shop  0.11
# 1  Fast Food Restaurant  0.07
# 2            Restaurant  0.05
# 3         Grocery Store  0.04
# 4      Sushi Restaurant  0.04
#
#
# ----L'Amoreaux West----
#                   venue  freq
# 0    Chinese Restaurant  0.10
# 1           Coffee Shop  0.07
# 2  Fast Food Restaurant  0.06
# 3              Pharmacy  0.06
# 4                  Park  0.04
#
#
# ----Lawrence Heights, Lawrence Manor----
#                    venue  freq
# 0         Clothing Store  0.09
# 1            Coffee Shop  0.07
# 2   Fast Food Restaurant  0.05
# 3             Restaurant  0.03
# 4  Vietnamese Restaurant  0.03
#
#
# ----Lawrence Park----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1              Bakery  0.04
# 2  Italian Restaurant  0.04
# 3            Pharmacy  0.03
# 4             Dog Run  0.03
#
#
# ----Leaside----
#                venue  freq
# 0        Coffee Shop  0.09
# 1  Indian Restaurant  0.08
# 2      Grocery Store  0.05
# 3        Supermarket  0.04
# 4         Restaurant  0.04
#
#
# ----Little Portugal, Trinity----
#                 venue  freq
# 0                Café  0.09
# 1                 Bar  0.07
# 2  Italian Restaurant  0.05
# 3        Cocktail Bar  0.05
# 4         Pizza Place  0.04
#
#
# ----Maryvale, Wexford----
#                        venue  freq
# 0                Coffee Shop  0.09
# 1                Pizza Place  0.05
# 2        American Restaurant  0.04
# 3  Middle Eastern Restaurant  0.04
# 4       Fast Food Restaurant  0.04
#
#
# ----Moore Park, Summerhill East----
#                 venue  freq
# 0  Italian Restaurant  0.09
# 1                Park  0.08
# 2                Café  0.07
# 3    Sushi Restaurant  0.06
# 4              Bakery  0.04
#
#
# ----Newtonbrook, Willowdale----
#                  venue  freq
# 0    Korean Restaurant  0.18
# 1          Coffee Shop  0.09
# 2      Bubble Tea Shop  0.06
# 3                 Bank  0.05
# 4  Japanese Restaurant  0.04
#
#
# ----North Toronto West----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1  Italian Restaurant  0.08
# 2                Café  0.07
# 3    Sushi Restaurant  0.05
# 4              Bakery  0.04
#
#
# ----Northwest----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1       Sandwich Place  0.09
# 2                Hotel  0.06
# 3         Burger Joint  0.06
# 4  American Restaurant  0.06
#
#
# ----Northwood Park, York University----
#             venue  freq
# 0     Coffee Shop  0.13
# 1  Sandwich Place  0.06
# 2     Pizza Place  0.05
# 3      Restaurant  0.05
# 4   Grocery Store  0.05
#
#
# ----Parkdale, Roncesvalles----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.08
# 2       Bakery  0.06
# 3          Bar  0.05
# 4         Park  0.05
#
#
# ----Parkwoods----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1             Pharmacy  0.06
# 2  Japanese Restaurant  0.06
# 3  Fried Chicken Joint  0.03
# 4       Sandwich Place  0.03
#
#
# ----Queen's Park----
#                            venue  freq
# 0                           Café  0.06
# 1                    Coffee Shop  0.05
# 2  Vegetarian / Vegan Restaurant  0.04
# 3            Japanese Restaurant  0.04
# 4                    Pizza Place  0.03
#
#
# ----Rosedale----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.07
# 2                Park  0.05
# 3                 Spa  0.03
# 4   French Restaurant  0.03
#
#
# ----Roselawn----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1   Italian Restaurant  0.08
# 2                 Café  0.04
# 3               Bakery  0.03
# 4  Sporting Goods Shop  0.03
#
#
# ----Rouge, Malvern----
#                   venue  freq
# 0           Zoo Exhibit  0.35
# 1  Fast Food Restaurant  0.10
# 2           Pizza Place  0.05
# 3                   Zoo  0.05
# 4    Athletics & Sports  0.05
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1              Bakery  0.06
# 2                Park  0.05
# 3  Italian Restaurant  0.05
# 4                Café  0.05
#
#
# ----Ryerson, Garden District----
#                  venue  freq
# 0                 Café  0.07
# 1          Coffee Shop  0.06
# 2            Gastropub  0.06
# 3  Japanese Restaurant  0.03
# 4      Thai Restaurant  0.03
#
#
# ----Scarborough Village----
#                   venue  freq
# 0  Fast Food Restaurant  0.14
# 1           Coffee Shop  0.11
# 2           Pizza Place  0.07
# 3              Pharmacy  0.06
# 4        Sandwich Place  0.06
#
#
# ----Silver Hills, York Mills----
#             venue  freq
# 0     Coffee Shop  0.13
# 1            Bank  0.05
# 2    Burger Joint  0.04
# 3     Pizza Place  0.04
# 4  Sandwich Place  0.03
#
#
# ----St. James Town----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1                 Café  0.07
# 2                Hotel  0.04
# 3            Gastropub  0.04
# 4  Japanese Restaurant  0.03
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#             venue  freq
# 0     Coffee Shop  0.07
# 1            Café  0.07
# 2           Hotel  0.06
# 3            Park  0.03
# 4  Farmers Market  0.03
#
#
# ----Studio District----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Park  0.07
# 2         Café  0.06
# 3       Bakery  0.05
# 4      Brewery  0.05
#
#
# ----The Annex, North Midtown, Yorkville----
#                 venue  freq
# 0         Coffee Shop  0.06
# 1  Italian Restaurant  0.04
# 2                Café  0.04
# 3       Grocery Store  0.03
# 4   French Restaurant  0.03
#
#
# ----The Beaches----
#          venue  freq
# 0  Coffee Shop  0.09
# 1          Pub  0.08
# 2        Beach  0.05
# 3          Bar  0.04
# 4       Bakery  0.04
#
#
# ----The Beaches West, India Bazaar----
#      venue  freq
# 0     Park  0.07
# 1     Café  0.06
# 2  Brewery  0.05
# 3    Beach  0.05
# 4      Bar  0.05
#
#
# ----The Danforth West, Riverdale----
#                    venue  freq
# 0       Greek Restaurant  0.08
# 1                   Café  0.07
# 2                   Park  0.06
# 3  Vietnamese Restaurant  0.04
# 4                 Bakery  0.04
#
#
# ----The Junction North, Runnymede----
#                 venue  freq
# 0  Italian Restaurant  0.05
# 1         Coffee Shop  0.05
# 2                Café  0.05
# 3       Grocery Store  0.05
# 4              Bakery  0.05
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1              Bakery  0.05
# 2  Italian Restaurant  0.05
# 3    Sushi Restaurant  0.04
# 4         Pizza Place  0.04
#
#
# ----Thorncliffe Park----
#               venue  freq
# 0       Coffee Shop  0.07
# 1    Sandwich Place  0.05
# 2     Grocery Store  0.04
# 3  Greek Restaurant  0.04
# 4        Restaurant  0.04
#
#
# ----Upper Rouge----
#               venue  freq
# 0              Farm   0.2
# 1             Trail   0.2
# 2     Grocery Store   0.2
# 3  Sculpture Garden   0.2
# 4       Golf Course   0.2
#
#
# ----Victoria Village----
#                   venue  freq
# 0           Coffee Shop  0.13
# 1  Fast Food Restaurant  0.09
# 2                   Gym  0.06
# 3         Grocery Store  0.04
# 4        Clothing Store  0.04
#
#
# ----Westmount----
#             venue  freq
# 0   Grocery Store  0.08
# 1  Sandwich Place  0.08
# 2     Coffee Shop  0.08
# 3     Pizza Place  0.08
# 4  Hardware Store  0.06
#
#
# ----Weston----
#                   venue  freq
# 0           Coffee Shop  0.10
# 1  Fast Food Restaurant  0.09
# 2        Sandwich Place  0.09
# 3           Pizza Place  0.07
# 4         Grocery Store  0.07
#
#
# ----Willowdale South----
#                venue  freq
# 0  Korean Restaurant  0.10
# 1    Bubble Tea Shop  0.05
# 2      Burrito Place  0.05
# 3        Supermarket  0.05
# 4   Sushi Restaurant  0.05
#
#
# ----Willowdale West----
#                        venue  freq
# 0                Coffee Shop  0.15
# 1                Pizza Place  0.08
# 2             Discount Store  0.08
# 3  Middle Eastern Restaurant  0.06
# 4                       Park  0.06
#
#
# ----Woburn----
#                     venue  freq
# 0             Coffee Shop  0.15
# 1    Fast Food Restaurant  0.10
# 2             Pizza Place  0.05
# 3       Indian Restaurant  0.03
# 4  Furniture / Home Store  0.03
#
#
# ----Woodbine Gardens, Parkview Hill----
#                   venue  freq
# 0           Pizza Place  0.07
# 1        Sandwich Place  0.05
# 2                  Park  0.05
# 3           Coffee Shop  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----Woodbine Heights----
#          venue  freq
# 0  Coffee Shop  0.06
# 1  Pizza Place  0.05
# 2         Park  0.04
# 3    Gastropub  0.04
# 4         Café  0.04
#
#
# ----York Mills West----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 
# 18                         Gym                Wings Joint
# 19                     Theater                       Park
# 20                         Bar                Pizza Place
# 21                         Bar              Grocery Store
# 22          Italian Restaurant        Japanese Restaurant
# 23                Burger Joint                 Shoe Store
# 24                        Park                   Pharmacy
# 25                    Pharmacy              Grocery Store
# 26               Grocery Store                       Park
# 27                     Theater                Pizza Place
# 28          Italian Restaurant           Sushi Restaurant
# 29          Italian Restaurant                       Park
# ..                         ...                        ...
# 73                        Park                        Bar
# 74              Sandwich Place         Chinese Restaurant
# 75         Japanese Restaurant             Cosmetics Shop
# 76                         Spa          French Restaurant
# 77                      Bakery  Middle Eastern Restaurant
# 78                         Zoo                Pizza Place
# 79          Italian Restaurant                       Café
# 80          Italian Restaurant        Japanese Restaurant
# 81                    Pharmacy             Sandwich Place
# 82                Burger Joint        Japanese Restaurant
# 83                       Hotel             Cosmetics Shop
# 84              Farmers Market         Seafood Restaurant
# 85                     Brewery                     Bakery
# 86                      Bakery                 Restaurant
# 87              Breakfast Spot                        Bar
# 88                     Brewery                        Bar
# 89       Vietnamese Restaurant                     Bakery
# 90                      Bakery         Italian Restaurant
# 91            Sushi Restaurant                Pizza Place
# 92               Grocery Store           Greek Restaurant
# 93                 Golf Course                       Farm
# 94              Clothing Store              Grocery Store
# 95              Sandwich Place             Hardware Store
# 96                 Pizza Place              Grocery Store
# 97             Bubble Tea Shop                       Café
# 98   Middle Eastern Restaurant                       Park
# 99                        Park             Discount Store
# 100       Fast Food Restaurant                       Park
# 101                       Park                       Café
# 102             Sandwich Place                   Pharmacy
#
#              6th Most Common Venue 7th Most Common Venue  \
# 0                      Pizza Place        Cosmetics Shop
# 1                   Sandwich Place  Cantonese Restaurant
# 2              Japanese Restaurant          Dessert Shop
# 3                   Sandwich Place                  Park
# 4                         Pharmacy        Breakfast Spot
# 5                             Bank     Convenience Store
# 6                    Shopping Mall                  Café
# 7               Italian Restaurant            Bagel Shop
# 8                        Gastropub    Italian Restaurant
# 9                       Beer Store      Asian Restaurant
# 10                  Baseball Field                  Park
# 11                          Bakery     Indian Restaurant
# 12              Italian Restaurant                   Bar
# 13           Vietnamese Restaurant           Pizza Place
# 14             Japanese Restaurant                Bakery
# 15              Italian Restaurant      Ramen Restaurant
# 16          Furniture / Home Store                  Bank
# 17                      Restaurant    Mexican Restaurant
# 18                        Pharmacy            Restaurant
# 19                      Restaurant         Burrito Place
# 20              Italian Restaurant                Bakery
# 21                     Pizza Place     Indian Restaurant
# 22                           Hotel                 Diner
# 23                   Grocery Store           Pizza Place
# 24                      Restaurant    Chinese Restaurant
# 25                  Sandwich Place                 Beach
# 26                  Sandwich Place           Pizza Place
# 27                       Gastropub        Cosmetics Shop
# 28             Japanese Restaurant             Gastropub
# 29                Sushi Restaurant     Indian Restaurant
# ..                             ...                   ...
# 73              Italian Restaurant            Restaurant
# 74                     Pizza Place   Fried Chicken Joint
# 75                            Park           Pizza Place
# 76                   Grocery Store            Restaurant
# 77             Japanese Restaurant            Restaurant
# 78                     Bus Station   Fried Chicken Joint
# 79                Sushi Restaurant         Grocery Store
# 80                     Pizza Place            Steakhouse
# 81              Chinese Restaurant         Grocery Store
# 82                      Restaurant                  Park
# 83                     Pizza Place    Italian Restaurant
# 84              Italian Restaurant             Gastropub
# 85           Vietnamese Restaurant                   Bar
# 86   Vegetarian / Vegan Restaurant         Grocery Store
# 87                          Bakery   Japanese Restaurant
# 88                     Coffee Shop                Bakery
# 89                  Ice Cream Shop    Italian Restaurant
# 90                             Bar          Burger Joint
# 91                             Pub                  Café
# 92                     Pizza Place              Pharmacy
# 93                   Event Service   Dumpling Restaurant
# 94                  Sandwich Place          Intersection
# 95                          Bakery         Train Station
# 96             Fried Chicken Joint            Beer Store
# 97                Sushi Restaurant        Clothing Store
# 98            Fast Food Restaurant         Grocery Store
# 99          Furniture / Home Store    Chinese Restaurant
# 100                        Brewery              Pharmacy
# 101                Thai Restaurant  Ethiopian Restaurant
# 102                     Restaurant   Fried Chicken Joint
#
#            8th Most Common Venue      9th Most Common Venue  \
# 0            Japanese Restaurant                Art Gallery
# 1                     Restaurant       Fast Food Restaurant
# 2                         Bakery          Korean Restaurant
# 3                     Beer Store        Fried Chicken Joint
# 4             Seafood Restaurant                       Café
# 5                  Deli / Bodega                 Bagel Shop
# 6                  Grocery Store                     Bakery
# 7                           Café                       Bank
# 8            Japanese Restaurant             Farmers Market
# 9           Fast Food Restaurant                   Pharmacy
# 10            Chinese Restaurant               Liquor Store
# 11            Italian Restaurant                  Gift Shop
# 12                         Diner        American Restaurant
# 13          Fast Food Restaurant              Jewelry Store
# 14                   Music Venue                    Brewery
# 15                         Diner        Japanese Restaurant
# 16                          Park             Breakfast Spot
# 17             Electronics Store             Breakfast Spot
# 18             Indian Restaurant             Sandwich Place
# 19                   Supermarket                   Tea Room
# 20            Mexican Restaurant                   Beer Bar
# 21                      Beer Bar                 Restaurant
# 22                   Pizza Place           Ramen Restaurant
# 23            Chinese Restaurant              Burrito Place
# 24                   Pizza Place             Sandwich Place
# 25                   Coffee Shop           Sushi Restaurant
# 26              Sushi Restaurant                   Pharmacy
# 27           Japanese Restaurant         Italian Restaurant
# 28                   Yoga Studio                       Park
# 29                           Gym        Japanese Restaurant
# ..                           ...                        ...
# 73              Sushi Restaurant                Pizza Place
# 74                Ice Cream Shop           Asian Restaurant
# 75                   Supermarket                        Bar
# 76           Japanese Restaurant                       Café
# 77           Sporting Goods Shop       Fast Food Restaurant
# 78          Caribbean Restaurant               Liquor Store
# 79                           Pub                      Diner
# 80               Thai Restaurant             Cosmetics Shop
# 81                  Liquor Store     Furniture / Home Store
# 82                   Supermarket                   Pharmacy
# 83           Japanese Restaurant             Farmers Market
# 84                    Restaurant                       Park
# 85             French Restaurant                 Restaurant
# 86             Korean Restaurant          French Restaurant
# 87                          Café            Thai Restaurant
# 88             Indian Restaurant        American Restaurant
# 89                   Pizza Place                        Pub
# 90                   Pizza Place                       Park
# 91                Sandwich Place               Liquor Store
# 92             Indian Restaurant        Japanese Restaurant
# 93   Eastern European Restaurant        Egyptian Restaurant
# 94           Japanese Restaurant  Middle Eastern Restaurant
# 95          Fast Food Restaurant                       Bank
# 96        Furniture / Home Store             Discount Store
# 97                        Bakery                    Theater
# 98             Korean Restaurant             Sandwich Place
# 99                   Supermarket                 Beer Store
# 100                Grocery Store                 Beer Store
# 101                          Pub             Ice Cream Shop
# 102                  Pizza Place                        Gym
#
#             10th Most Common Venue
# 0                       Restaurant
# 1                           Bakery
# 2            Vietnamese Restaurant
# 3                             Café
# 4                Electronics Store
# 5                       Restaurant
# 6                Korean Restaurant
# 7                      Pizza Place
# 8               Seafood Restaurant
# 9                            Diner
# 10            Gym / Fitness Center
# 11              Athletics & Sports
# 12                           Beach
# 13                     Men's Store
# 14                  Scenic Lookout
# 15                 Thai Restaurant
# 16              Mexican Restaurant
# 17                   Burrito Place
# 18                     Pizza Place
# 19                       Bookstore
# 20                    Cocktail Bar
# 21   Vegetarian / Vegan Restaurant
# 22                      Restaurant
# 23                  Clothing Store
# 24              Falafel Restaurant
# 25                          Bistro
# 26               Fish & Chips Shop
# 27                 Thai Restaurant
# 28                             Gym
# 29             Sporting Goods Shop
# ..                             ...
# 73     Eastern European Restaurant
# 74                        Bus Stop
# 75                Ramen Restaurant
# 76                    Dance Studio
# 77                           Trail
# 78            Other Great Outdoors
# 79                      Restaurant
# 80                             Pub
# 81                            Park
# 82                            Café
# 83                      Restaurant
# 84                  Cosmetics Shop
# 85                     Pizza Place
# 86             Japanese Restaurant
# 87                            Park
# 88              Italian Restaurant
# 89                     Coffee Shop
# 90              Mexican Restaurant
# 91                    Burger Joint
# 92                    Burger Joint
# 93               Electronics Store
# 94            Gym / Fitness Center
# 95                  Discount Store
# 96                   Train Station
# 97                 Thai Restaurant
# 98                        Pharmacy
# 99               Indian Restaurant
# 100                   Skating Rink
# 101                       Pharmacy
# 102                  Grocery Store
#
# [103 rows x 11 columns]

# %% [markdown]
# # Cluster the neighborhoods in Toronto

# %% [markdown]
# Let's cluster the neighborhoods in 5 cluster.

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhoods', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

toronto_merged = neighborhoods

# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhoods'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postalcode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353               1           Zoo Exhibit  Fast Food Restaurant
# 1 -79.160497               2        Breakfast Spot           Coffee Shop
# 2 -79.188711               2           Pizza Place                  Park
# 3 -79.216917               0           Coffee Shop  Fast Food Restaurant
# 4 -79.239476               2           Coffee Shop        Clothing Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0    Athletics & Sports                   Zoo           Pizza Place
# 1             Pet Store        Sandwich Place        Ice Cream Shop
# 2           Coffee Shop  Fast Food Restaurant        Breakfast Spot
# 3           Pizza Place                  Park        Discount Store
# 4  Fast Food Restaurant                   Gym           Wings Joint
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0             Bus Station   Fried Chicken Joint  Caribbean Restaurant
# 1                     Bar          Liquor Store            Beer Store
# 2        Storage Facility      Greek Restaurant                  Bank
# 3  Furniture / Home Store    Chinese Restaurant           Supermarket
# 4                Pharmacy            Restaurant     Indian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0          Liquor Store   Other Great Outdoors
# 1           Supermarket    Fried Chicken Joint
# 2                   Bar           Liquor Store
# 3            Beer Store      Indian Restaurant
# 4        Sandwich Place            Pizza Place

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
